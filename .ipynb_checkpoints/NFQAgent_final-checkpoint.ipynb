# %%
# Reference: https://www.cs.toronto.edu/~vmnih/docs/dqn.pdf

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
#from torch.utils.tensorboard import SummaryWriter

import argparse
from distutils.util import strtobool
import collections
import numpy as np
import gym
from gym.wrappers import TimeLimit, Monitor
from gym.spaces import Discrete, Box, MultiBinary, MultiDiscrete, Space
import time
import random
import os
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):

# %%
# TRY NOT TO MODIFY: seeding
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

env = gym.make('Humanoid-v2')
seed = 1234
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
env.seed(seed)

# Hyper params
#discrete_action_space_dim = 101
discrete_action_space_dim = 21
input_dim = env.observation_space.shape[0]
#hidden_dim = 765
hidden_dim = 765
output_dim = env.action_space.shape[0] * discrete_action_space_dim
#output_dim = train_env.action_space.shape[0]
print (input_dim, output_dim)
# Out:
# /home/gswatiseas/gym/gym/envs/registration.py:579: UserWarning: WARN: The environment Humanoid-v2 is out of date. You should consider upgrading to version v3 with the environment ID `Humanoid-v3`.
#   f"The environment {spec.id} is out of date. You should consider "
# 376 357

# %%
def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.kaiming_normal_(m.weight)
        m.bias.data.fill_(0)

# %%
# modified from https://github.com/seungeunrho/minimalRL/blob/master/dqn.py#
class ReplayBuffer():
    def __init__(self, buffer_limit):
        self.buffer = collections.deque(maxlen=buffer_limit)
    
    def put(self, transition):
        #print ("transition: ", len(transition))
        self.buffer.append(transition)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
        
        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append(a)
            r_lst.append(r)
            s_prime_lst.append(s_prime)
            done_mask_lst.append(done_mask)

        return np.array(s_lst), np.array(a_lst), \
               np.array(r_lst), np.array(s_prime_lst), \
               np.array(done_mask_lst)
    def flush(self):
        self.buffer.clear()
        
    def len(self):
        return (len(self.buffer))
        

# ALGO LOGIC: initialize agent here:
class QNetwork(nn.Module):
    def __init__(self, env):
        super(QNetwork, self).__init__()
        self.fc_1 = nn.Linear(input_dim, hidden_dim)
        self.fc_1a = nn.Linear(hidden_dim, hidden_dim)
        self.fc_2 = nn.Linear(hidden_dim, output_dim)
        self.maxpool = nn.MaxPool1d(discrete_action_space_dim, stride=discrete_action_space_dim, return_indices=True)

    def forward(self, x, device):
        x = torch.FloatTensor(x).to(device)
        x = torch.tanh(self.fc_1(x))
        x = torch.tanh(self.fc_1a(x))
        x = self.fc_2(x)
        x1, indices = self.maxpool(x)
        return x1, indices

def linear_schedule(start_e: float, end_e: float, duration: int, t: int):
    slope =  (end_e - start_e) / duration
    return max(slope * t + start_e, end_e)

# %%
n = discrete_action_space_dim
max_action = 0.4
min_action = -0.4
inc = (max_action - min_action)/ (n-1)
print (inc)
discrete_action_list = [min_action+inc*i for i in range(0, n)]
print (len(discrete_action_list))
# Out:
# 0.04
# 21

# %%
def get_actions(action_indices):
    ret_actions = np.zeros(env.action_space.shape[0])
    for i in range(0, len(action_indices)):
        index = action_indices[i] - i*discrete_action_space_dim
        ret_actions[i] = discrete_action_list[index]
    return ret_actions

# %%
buffer_size = 100_000
lr = 1e-5

rb = ReplayBuffer(buffer_size)
nfq_network = QNetwork(env).to(device)
nfq_network.apply(init_weights)
optimizer = optim.RMSprop(nfq_network.parameters(), lr=lr)
loss_fn = nn.MSELoss()
print(device.__repr__())
print(nfq_network)

batch_size = 64
max_grad_norm = 1.0
gamma = 0.99

# Hyper params
n_iters = 30
steps_per_iter = 4000
phase = 'train'
max_step = 1000
# Out:
# device(type='cuda')
# QNetwork(
#   (fc_1): Linear(in_features=376, out_features=765, bias=True)
#   (fc_1a): Linear(in_features=765, out_features=765, bias=True)
#   (fc_2): Linear(in_features=765, out_features=357, bias=True)
#   (maxpool): MaxPool1d(kernel_size=21, stride=21, padding=0, dilation=1, ceil_mode=False)
# )

# %%
def agent_run(max_steps, global_steps, epsilon):
    episode = 0
    episode_rewards = []
    step_rewards = []

    obs = env.reset()
    episode_reward = 0
    step_count = 0
    for step in range(max_steps):
        if random.random() < epsilon:
            action = env.action_space.sample()
        else:
            q_vals, action_indices = nfq_network.forward(obs[None, :], device)
            action = get_actions(action_indices.view((-1)))

        next_obs, reward, done, _ = env.step(action)
        episode_reward += reward
        step_rewards.append(reward)

        rb.put((obs, action, reward, next_obs, done))
    
        if step - batch_size > 0:
            s_obs, s_actions, s_rewards, s_next_obses, s_dones = rb.sample(batch_size)
            with torch.no_grad():
                q_next_val, action_next_indices = nfq_network.forward(s_next_obses, device)
                target_max = q_next_val.sum()
                td_target = torch.Tensor(s_rewards).to(device) + gamma * target_max * (1 - torch.Tensor(s_dones).to(device))

            old_q, old_action = nfq_network.forward(s_obs, device)

            loss = loss_fn(td_target, torch.sum(old_q, 1))

            # optimize the midel
            optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(list(nfq_network.parameters()), max_grad_norm)
            optimizer.step()

        # TRY NOT TO MODIFY: CRUCIAL step easy to overlook 
        obs = next_obs
        step_count +=1
        
        if done:
            break
            
    return step_count, episode_reward

# %%
start_time = time.time()

total_num_steps = 0
train_sum_returns = 0.
train_num_episodes = 0
eval_mode = False

train_avg_ret = []
train_ep_ret = []
eval_avg_ret = []
eval_ep_ret = []
epsilon = 0.9
decay_rate = 0.9975

for i in range(n_iters):
        # Perform the training phase, during which the agent learns
        if phase == 'train':
            train_step_count = 0
            while train_step_count <= steps_per_iter:
                eval_mode = False
                epsilon = max(epsilon*decay_rate, 0.1)
                
                # Run one episode
                train_step_length, train_episode_return = agent_run(max_step, i, epsilon)
                
                total_num_steps += train_step_length
                train_step_count += train_step_length
                train_sum_returns += train_episode_return
                train_num_episodes += 1

                train_average_return = train_sum_returns / train_num_episodes if train_num_episodes > 0 else 0.0
                
                train_avg_ret.append(train_average_return)
                train_ep_ret.append(train_episode_return)


        # Perform the evaluation phase -- no learning
        eval_sum_returns = 0.
        eval_num_episodes = 0
        eval_mode = True

        for _ in range(10):
            # Run one episode
            eval_step_length, eval_episode_return = agent_run(max_step, i, 0)

            eval_sum_returns += eval_episode_return
            eval_num_episodes += 1

        eval_average_return = eval_sum_returns / eval_num_episodes if eval_num_episodes > 0 else 0.0
        eval_avg_ret.append(eval_average_return)
        eval_ep_ret.append(eval_episode_return)


        if phase == 'train':
            print('---------------------------------------')
            print('Iterations:', i + 1)
            print('Steps:', total_num_steps)
            print('Episodes:', train_num_episodes)
            print('EpisodeReturn:', round(train_episode_return, 2))
            print('AverageReturn:', round(train_average_return, 2))
            print('EvalEpisodes:', eval_num_episodes)
            print('EvalEpisodeReturn:', round(eval_episode_return, 2))
            print('EvalAverageReturn:', round(eval_average_return, 2))
            print('Time:', int(time.time() - start_time))
            print('---------------------------------------')
        else:
            print('---------------------------------------')
            print('EvalEpisodes:', eval_num_episodes)
            print('EvalEpisodeReturn:', round(eval_episode_return, 2))
            print('EvalAverageReturn:', round(eval_average_return, 2))
            print('Time:', int(time.time() - start_time))
            print('---------------------------------------')
# Out:
# ---------------------------------------
# Iterations: 1
# Steps: 4029
# Episodes: 168
# EpisodeReturn: 192.17
# AverageReturn: 120.57
# EvalEpisodes: 10
# EvalEpisodeReturn: 110.91
# EvalAverageReturn: 118.09
# Time: 3
# ---------------------------------------
# ---------------------------------------
# Iterations: 2
# Steps: 8041
# Episodes: 336
# EpisodeReturn: 109.15
# AverageReturn: 120.51
# EvalEpisodes: 10
# EvalEpisodeReturn: 106.3
# EvalAverageReturn: 109.27
# Time: 7
# ---------------------------------------
# ---------------------------------------
# Iterations: 3
# Steps: 12043
# Episodes: 495
# EpisodeReturn: 134.0
# AverageReturn: 122.73
# EvalEpisodes: 10
# EvalEpisodeReturn: 111.36
# EvalAverageReturn: 113.47
# Time: 12
# ---------------------------------------
# ---------------------------------------
# Iterations: 4
# Steps: 16052
# Episodes: 660
# EpisodeReturn: 116.9
# AverageReturn: 122.68
# EvalEpisodes: 10
# EvalEpisodeReturn: 94.85
# EvalAverageReturn: 117.03
# Time: 18
# ---------------------------------------
# ---------------------------------------
# Iterations: 5
# Steps: 20082
# Episodes: 829
# EpisodeReturn: 190.64
# AverageReturn: 122.25
# EvalEpisodes: 10
# EvalEpisodeReturn: 105.43
# EvalAverageReturn: 121.97
# Time: 23
# ---------------------------------------
# ---------------------------------------
# Iterations: 6
# Steps: 24095
# Episodes: 989
# EpisodeReturn: 220.7
# AverageReturn: 122.96
# EvalEpisodes: 10
# EvalEpisodeReturn: 228.62
# EvalAverageReturn: 237.94
# Time: 30
# ---------------------------------------
# ---------------------------------------
# Iterations: 7
# Steps: 28111
# Episodes: 1099
# EpisodeReturn: 224.99
# AverageReturn: 129.28
# EvalEpisodes: 10
# EvalEpisodeReturn: 234.88
# EvalAverageReturn: 250.55
# Time: 36
# ---------------------------------------
# ---------------------------------------
# Iterations: 8
# Steps: 32122
# Episodes: 1200
# EpisodeReturn: 169.45
# AverageReturn: 135.5
# EvalEpisodes: 10
# EvalEpisodeReturn: 307.12
# EvalAverageReturn: 300.79
# Time: 43
# ---------------------------------------
# ---------------------------------------
# Iterations: 9
# Steps: 36142
# Episodes: 1286
# EpisodeReturn: 184.61
# AverageReturn: 142.79
# EvalEpisodes: 10
# EvalEpisodeReturn: 346.88
# EvalAverageReturn: 336.87
# Time: 56
# ---------------------------------------
# ---------------------------------------
# Iterations: 10
# Steps: 40159
# Episodes: 1368
# EpisodeReturn: 431.65
# AverageReturn: 149.73
# EvalEpisodes: 10
# EvalEpisodeReturn: 309.05
# EvalAverageReturn: 305.54
# Time: 69
# ---------------------------------------
# ---------------------------------------
# Iterations: 11
# Steps: 44174
# Episodes: 1455
# EpisodeReturn: 151.65
# AverageReturn: 155.25
# EvalEpisodes: 10
# EvalEpisodeReturn: 327.0
# EvalAverageReturn: 310.7
# Time: 82
# ---------------------------------------
# ---------------------------------------
# Iterations: 12
# Steps: 48226
# Episodes: 1541
# EpisodeReturn: 292.27
# AverageReturn: 160.47
# EvalEpisodes: 10
# EvalEpisodeReturn: 324.83
# EvalAverageReturn: 314.88
# Time: 96
# ---------------------------------------
# ---------------------------------------
# Iterations: 13
# Steps: 52279
# Episodes: 1630
# EpisodeReturn: 360.21
# AverageReturn: 164.77
# EvalEpisodes: 10
# EvalEpisodeReturn: 283.87
# EvalAverageReturn: 287.58
# Time: 111
# ---------------------------------------
# ---------------------------------------
# Iterations: 14
# Steps: 56317
# Episodes: 1715
# EpisodeReturn: 312.05
# AverageReturn: 169.04
# EvalEpisodes: 10
# EvalEpisodeReturn: 280.9
# EvalAverageReturn: 282.97
# Time: 130
# ---------------------------------------
# ---------------------------------------
# Iterations: 15
# Steps: 60341
# Episodes: 1800
# EpisodeReturn: 155.9
# AverageReturn: 172.81
# EvalEpisodes: 10
# EvalEpisodeReturn: 281.38
# EvalAverageReturn: 287.9
# Time: 149
# ---------------------------------------
# ---------------------------------------
# Iterations: 16
# Steps: 64381
# Episodes: 1889
# EpisodeReturn: 213.27
# AverageReturn: 175.99
# EvalEpisodes: 10
# EvalEpisodeReturn: 285.7
# EvalAverageReturn: 288.52
# Time: 168
# ---------------------------------------
# ---------------------------------------
# Iterations: 17
# Steps: 68382
# Episodes: 1978
# EpisodeReturn: 165.4
# AverageReturn: 178.73
# EvalEpisodes: 10
# EvalEpisodeReturn: 284.09
# EvalAverageReturn: 287.28
# Time: 186
# ---------------------------------------
# ---------------------------------------
# Iterations: 18
# Steps: 72412
# Episodes: 2070
# EpisodeReturn: 226.85
# AverageReturn: 181.08
# EvalEpisodes: 10
# EvalEpisodeReturn: 279.18
# EvalAverageReturn: 285.02
# Time: 204
# ---------------------------------------
# ---------------------------------------
# Iterations: 19
# Steps: 76448
# Episodes: 2156
# EpisodeReturn: 266.81
# AverageReturn: 183.74
# EvalEpisodes: 10
# EvalEpisodeReturn: 288.44
# EvalAverageReturn: 286.89
# Time: 223
# ---------------------------------------
# ---------------------------------------
# Iterations: 20
# Steps: 80454
# Episodes: 2248
# EpisodeReturn: 209.14
# AverageReturn: 185.61
# EvalEpisodes: 10
# EvalEpisodeReturn: 282.29
# EvalAverageReturn: 287.39
# Time: 241
# ---------------------------------------
# ---------------------------------------
# Iterations: 21
# Steps: 84466
# Episodes: 2330
# EpisodeReturn: 269.55
# AverageReturn: 188.14
# EvalEpisodes: 10
# EvalEpisodeReturn: 297.34
# EvalAverageReturn: 288.69
# Time: 260
# ---------------------------------------
# ---------------------------------------
# Iterations: 22
# Steps: 88484
# Episodes: 2413
# EpisodeReturn: 375.36
# AverageReturn: 190.48
# EvalEpisodes: 10
# EvalEpisodeReturn: 277.69
# EvalAverageReturn: 283.93
# Time: 279
# ---------------------------------------
# ---------------------------------------
# Iterations: 23
# Steps: 92487
# Episodes: 2499
# EpisodeReturn: 280.45
# AverageReturn: 192.39
# EvalEpisodes: 10
# EvalEpisodeReturn: 289.45
# EvalAverageReturn: 287.19
# Time: 297
# ---------------------------------------
# ---------------------------------------
# Iterations: 24
# Steps: 96498
# Episodes: 2587
# EpisodeReturn: 161.67
# AverageReturn: 193.97
# EvalEpisodes: 10
# EvalEpisodeReturn: 288.5
# EvalAverageReturn: 288.33
# Time: 316
# ---------------------------------------
# ---------------------------------------
# Iterations: 25
# Steps: 100511
# Episodes: 2673
# EpisodeReturn: 240.91
# AverageReturn: 195.65
# EvalEpisodes: 10
# EvalEpisodeReturn: 284.98
# EvalAverageReturn: 287.07
# Time: 334
# ---------------------------------------
# ---------------------------------------
# Iterations: 26
# Steps: 104518
# Episodes: 2760
# EpisodeReturn: 191.28
# AverageReturn: 197.13
# EvalEpisodes: 10
# EvalEpisodeReturn: 276.76
# EvalAverageReturn: 292.46
# Time: 353
# ---------------------------------------
# ---------------------------------------
# Iterations: 27
# Steps: 108542
# Episodes: 2848
# EpisodeReturn: 234.38
# AverageReturn: 198.49
# EvalEpisodes: 10
# EvalEpisodeReturn: 285.59
# EvalAverageReturn: 285.78
# Time: 371
# ---------------------------------------
# ---------------------------------------
# Iterations: 28
# Steps: 112578
# Episodes: 2935
# EpisodeReturn: 209.07
# AverageReturn: 199.88
# EvalEpisodes: 10
# EvalEpisodeReturn: 283.02
# EvalAverageReturn: 284.04
# Time: 390
# ---------------------------------------
# ---------------------------------------
# Iterations: 29
# Steps: 116621
# Episodes: 3020
# EpisodeReturn: 338.22
# AverageReturn: 201.32
# EvalEpisodes: 10
# EvalEpisodeReturn: 293.5
# EvalAverageReturn: 291.58
# Time: 409
# ---------------------------------------
# ---------------------------------------
# Iterations: 30
# Steps: 120630
# Episodes: 3110
# EpisodeReturn: 301.83
# AverageReturn: 202.29
# EvalEpisodes: 10
# EvalEpisodeReturn: 279.43
# EvalAverageReturn: 283.66
# Time: 427
# ---------------------------------------

# %%
plt.show()
plt.plot(train_avg_ret)
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.title("train average rewards")

plt.show()
plt.plot(train_ep_ret)
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.title("train episode rewards")
# Out:
# Text(0.5, 1.0, 'train episode rewards')

# %%
plt.show()
plt.plot(eval_avg_ret)
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.title("test average rewards")

plt.show()
plt.plot(eval_ep_ret)
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.title("test episode rewards")
# Out:
# Text(0.5, 1.0, 'test episode rewards')

# %%
flag = "good"

# %%
from datetime import datetime

now = datetime.now() # current date and time
date_time = str(now.strftime("%m:%d:%Y_%H:%M:%S"))
print (date_time)


algo = "NFQAgent"
path = "Results/" + algo + date_time + flag
np.save(path +"_train_avg", train_avg_ret)
np.save(path + "_test_avg", eval_avg_ret)
np.save(path +"_train_ep", train_ep_ret)
np.save(path + "_test_ep", eval_ep_ret)

# %%
torch.save(nfq_network, path+"model")
