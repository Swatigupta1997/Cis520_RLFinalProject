# %%
# Reference: https://www.cs.toronto.edu/~vmnih/docs/dqn.pdf

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
#from torch.utils.tensorboard import SummaryWriter

import argparse
from distutils.util import strtobool
import collections
import numpy as np
import gym
from gym.wrappers import TimeLimit, Monitor
from gym.spaces import Discrete, Box, MultiBinary, MultiDiscrete, Space
import time
import random
import os
import matplotlib.pyplot as plt
# Out:
# /opt/conda/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):

# %%
# TRY NOT TO MODIFY: seeding
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

env = gym.make('Humanoid-v2')
seed = 1234
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
env.seed(seed)

# Hyper params
#discrete_action_space_dim = 101
discrete_action_space_dim = 21
input_dim = env.observation_space.shape[0]
#hidden_dim = 765
hidden_dim = 765
output_dim = env.action_space.shape[0] * discrete_action_space_dim
#output_dim = train_env.action_space.shape[0]
print (input_dim, output_dim)
# Out:
# /home/gswatiseas/gym/gym/envs/registration.py:579: UserWarning: WARN: The environment Humanoid-v2 is out of date. You should consider upgrading to version v3 with the environment ID `Humanoid-v3`.
#   f"The environment {spec.id} is out of date. You should consider "
# 376 357

# %%
# modified from https://github.com/seungeunrho/minimalRL/blob/master/dqn.py#
class ReplayBuffer():
    def __init__(self, buffer_limit):
        self.buffer = collections.deque(maxlen=buffer_limit)
    
    def put(self, transition):
        #print ("transition: ", len(transition))
        self.buffer.append(transition)
    
    def sample(self, n):
        mini_batch = random.sample(self.buffer, n)
        s_lst, a_lst, r_lst, s_prime_lst, done_mask_lst = [], [], [], [], []
        
        for transition in mini_batch:
            s, a, r, s_prime, done_mask = transition
            s_lst.append(s)
            a_lst.append(a)
            r_lst.append(r)
            s_prime_lst.append(s_prime)
            done_mask_lst.append(done_mask)

        return np.array(s_lst), np.array(a_lst), \
               np.array(r_lst), np.array(s_prime_lst), \
               np.array(done_mask_lst)
    def flush(self):
        self.buffer.clear()
        
    def len(self):
        return (len(self.buffer))
        

# ALGO LOGIC: initialize agent here:
class QNetwork(nn.Module):
    def __init__(self, env):
        super(QNetwork, self).__init__()
        self.fc_1 = nn.Linear(input_dim, hidden_dim)
        self.fc_1a = nn.Linear(hidden_dim, hidden_dim)
        self.fc_2 = nn.Linear(hidden_dim, output_dim)
        self.maxpool = nn.MaxPool1d(discrete_action_space_dim, stride=discrete_action_space_dim, return_indices=True)

    def forward(self, x, device):
        x = torch.FloatTensor(x).to(device)
        x = torch.tanh(self.fc_1(x))
        x = torch.tanh(self.fc_1a(x))
        x = self.fc_2(x)
        x1, indices = self.maxpool(x)
        return x1, indices

def linear_schedule(start_e: float, end_e: float, duration: int, t: int):
    slope =  (end_e - start_e) / duration
    return max(slope * t + start_e, end_e)

# %%
n = discrete_action_space_dim
max_action = 0.4
min_action = -0.4
inc = (max_action - min_action)/ (n-1)
print (inc)
discrete_action_list = [min_action+inc*i for i in range(0, n)]
print (len(discrete_action_list))
# Out:
# 0.04
# 21

# %%
def get_actions(action_indices):
    ret_actions = np.zeros(env.action_space.shape[0])
    for i in range(0, len(action_indices)):
        index = action_indices[i] - i*discrete_action_space_dim
        ret_actions[i] = discrete_action_list[index]
    return ret_actions

# %%
buffer_size = 100_000
lr = 1e-5

rb = ReplayBuffer(buffer_size)
nfq_network = QNetwork(env).to(device)
optimizer = optim.RMSprop(nfq_network.parameters(), lr=lr)
loss_fn = nn.MSELoss()
print(device.__repr__())
print(nfq_network)

batch_size = 64
max_grad_norm = 1.0
gamma = 0.99

# Hyper params
n_iters = 30
steps_per_iter = 4000
phase = 'train'
max_step = 1000
# Out:
# device(type='cuda')
# QNetwork(
#   (fc_1): Linear(in_features=376, out_features=765, bias=True)
#   (fc_1a): Linear(in_features=765, out_features=765, bias=True)
#   (fc_2): Linear(in_features=765, out_features=357, bias=True)
#   (maxpool): MaxPool1d(kernel_size=21, stride=21, padding=0, dilation=1, ceil_mode=False)
# )

# %%
def agent_run(max_steps, global_steps, epsilon):
    episode = 0
    episode_rewards = []
    step_rewards = []

    obs = env.reset()
    episode_reward = 0
    step_count = 0
    for step in range(max_steps):
        if random.random() < epsilon:
            action = env.action_space.sample()
        else:
            q_vals, action_indices = nfq_network.forward(obs[None, :], device)
            action = get_actions(action_indices.view((-1)))

        next_obs, reward, done, _ = env.step(action)
        episode_reward += reward
        step_rewards.append(reward)

        rb.put((obs, action, reward, next_obs, done))
    
        if step - batch_size > 0:
            s_obs, s_actions, s_rewards, s_next_obses, s_dones = rb.sample(batch_size)
            with torch.no_grad():
                q_next_val, action_next_indices = nfq_network.forward(s_next_obses, device)
                target_max = q_next_val.sum()
                td_target = torch.Tensor(s_rewards).to(device) + gamma * target_max * (1 - torch.Tensor(s_dones).to(device))

            old_q, old_action = nfq_network.forward(s_obs, device)

            loss = loss_fn(td_target, torch.sum(old_q, 1))

            # optimize the midel
            optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(list(nfq_network.parameters()), max_grad_norm)
            optimizer.step()

        # TRY NOT TO MODIFY: CRUCIAL step easy to overlook 
        obs = next_obs
        step_count +=1
        
        if done:
            break
            
    return step_count, episode_reward

# %%
start_time = time.time()

total_num_steps = 0
train_sum_returns = 0.
train_num_episodes = 0
eval_mode = False

train_avg_ret = []
train_ep_ret = []
eval_avg_ret = []
eval_ep_ret = []
epsilon = 0.9
decay_rate = 0.9975

for i in range(n_iters):
        # Perform the training phase, during which the agent learns
        if phase == 'train':
            train_step_count = 0
            while train_step_count <= steps_per_iter:
                eval_mode = False
                epsilon = max(epsilon*decay_rate, 0.1)
                
                # Run one episode
                train_step_length, train_episode_return = agent_run(max_step, i, epsilon)
                
                total_num_steps += train_step_length
                train_step_count += train_step_length
                train_sum_returns += train_episode_return
                train_num_episodes += 1

                train_average_return = train_sum_returns / train_num_episodes if train_num_episodes > 0 else 0.0
                
                train_avg_ret.append(train_average_return)
                train_ep_ret.append(train_episode_return)


        # Perform the evaluation phase -- no learning
        eval_sum_returns = 0.
        eval_num_episodes = 0
        eval_mode = True

        for _ in range(10):
            # Run one episode
            eval_step_length, eval_episode_return = agent_run(max_step, i, 0)

            eval_sum_returns += eval_episode_return
            eval_num_episodes += 1

        eval_average_return = eval_sum_returns / eval_num_episodes if eval_num_episodes > 0 else 0.0
        eval_avg_ret.append(eval_average_return)
        eval_ep_ret.append(eval_episode_return)


        if phase == 'train':
            print('---------------------------------------')
            print('Iterations:', i + 1)
            print('Steps:', total_num_steps)
            print('Episodes:', train_num_episodes)
            print('EpisodeReturn:', round(train_episode_return, 2))
            print('AverageReturn:', round(train_average_return, 2))
            print('EvalEpisodes:', eval_num_episodes)
            print('EvalEpisodeReturn:', round(eval_episode_return, 2))
            print('EvalAverageReturn:', round(eval_average_return, 2))
            print('Time:', int(time.time() - start_time))
            print('---------------------------------------')
        else:
            print('---------------------------------------')
            print('EvalEpisodes:', eval_num_episodes)
            print('EvalEpisodeReturn:', round(eval_episode_return, 2))
            print('EvalAverageReturn:', round(eval_average_return, 2))
            print('Time:', int(time.time() - start_time))
            print('---------------------------------------')
# Out:
# ---------------------------------------
# Iterations: 1
# Steps: 4026
# Episodes: 159
# EpisodeReturn: 266.49
# AverageReturn: 127.21
# EvalEpisodes: 10
# EvalEpisodeReturn: 164.69
# EvalAverageReturn: 157.25
# Time: 6
# ---------------------------------------
# ---------------------------------------
# Iterations: 2
# Steps: 8037
# Episodes: 305
# EpisodeReturn: 149.23
# AverageReturn: 132.45
# EvalEpisodes: 10
# EvalEpisodeReturn: 141.96
# EvalAverageReturn: 182.5
# Time: 14
# ---------------------------------------
# ---------------------------------------
# Iterations: 3
# Steps: 12038
# Episodes: 446
# EpisodeReturn: 88.67
# AverageReturn: 135.72
# EvalEpisodes: 10
# EvalEpisodeReturn: 160.99
# EvalAverageReturn: 143.24
# Time: 24
# ---------------------------------------
# ---------------------------------------
# Iterations: 4
# Steps: 16052
# Episodes: 593
# EpisodeReturn: 198.4
# AverageReturn: 136.36
# EvalEpisodes: 10
# EvalEpisodeReturn: 166.49
# EvalAverageReturn: 171.17
# Time: 35
# ---------------------------------------
# ---------------------------------------
# Iterations: 5
# Steps: 20062
# Episodes: 733
# EpisodeReturn: 156.84
# AverageReturn: 138.19
# EvalEpisodes: 10
# EvalEpisodeReturn: 142.54
# EvalAverageReturn: 166.5
# Time: 45
# ---------------------------------------
# ---------------------------------------
# Iterations: 6
# Steps: 24073
# Episodes: 873
# EpisodeReturn: 166.67
# AverageReturn: 139.53
# EvalEpisodes: 10
# EvalEpisodeReturn: 189.27
# EvalAverageReturn: 180.75
# Time: 57
# ---------------------------------------
# ---------------------------------------
# Iterations: 7
# Steps: 28086
# Episodes: 1011
# EpisodeReturn: 170.56
# AverageReturn: 140.82
# EvalEpisodes: 10
# EvalEpisodeReturn: 113.92
# EvalAverageReturn: 161.34
# Time: 69
# ---------------------------------------
# ---------------------------------------
# Iterations: 8
# Steps: 32087
# Episodes: 1149
# EpisodeReturn: 198.53
# AverageReturn: 141.79
# EvalEpisodes: 10
# EvalEpisodeReturn: 143.92
# EvalAverageReturn: 169.86
# Time: 81
# ---------------------------------------
# ---------------------------------------
# Iterations: 9
# Steps: 36108
# Episodes: 1285
# EpisodeReturn: 106.62
# AverageReturn: 142.83
# EvalEpisodes: 10
# EvalEpisodeReturn: 188.24
# EvalAverageReturn: 177.95
# Time: 94
# ---------------------------------------
# ---------------------------------------
# Iterations: 10
# Steps: 40131
# Episodes: 1416
# EpisodeReturn: 186.93
# AverageReturn: 144.18
# EvalEpisodes: 10
# EvalEpisodeReturn: 186.57
# EvalAverageReturn: 187.69
# Time: 106
# ---------------------------------------
# ---------------------------------------
# Iterations: 11
# Steps: 44143
# Episodes: 1557
# EpisodeReturn: 176.88
# AverageReturn: 144.37
# EvalEpisodes: 10
# EvalEpisodeReturn: 201.05
# EvalAverageReturn: 163.84
# Time: 118
# ---------------------------------------
# ---------------------------------------
# Iterations: 12
# Steps: 48161
# Episodes: 1694
# EpisodeReturn: 140.71
# AverageReturn: 144.9
# EvalEpisodes: 10
# EvalEpisodeReturn: 156.51
# EvalAverageReturn: 166.04
# Time: 130
# ---------------------------------------
# ---------------------------------------
# Iterations: 13
# Steps: 52178
# Episodes: 1825
# EpisodeReturn: 183.12
# AverageReturn: 145.83
# EvalEpisodes: 10
# EvalEpisodeReturn: 113.97
# EvalAverageReturn: 174.25
# Time: 143
# ---------------------------------------
# ---------------------------------------
# Iterations: 14
# Steps: 56217
# Episodes: 1962
# EpisodeReturn: 235.18
# AverageReturn: 146.2
# EvalEpisodes: 10
# EvalEpisodeReturn: 216.92
# EvalAverageReturn: 167.3
# Time: 154
# ---------------------------------------
# ---------------------------------------
# Iterations: 15
# Steps: 60244
# Episodes: 2098
# EpisodeReturn: 148.47
# AverageReturn: 146.59
# EvalEpisodes: 10
# EvalEpisodeReturn: 205.7
# EvalAverageReturn: 165.17
# Time: 165
# ---------------------------------------
# ---------------------------------------
# Iterations: 16
# Steps: 64265
# Episodes: 2231
# EpisodeReturn: 129.96
# AverageReturn: 147.1
# EvalEpisodes: 10
# EvalEpisodeReturn: 150.87
# EvalAverageReturn: 162.37
# Time: 175
# ---------------------------------------
# ---------------------------------------
# Iterations: 17
# Steps: 68294
# Episodes: 2359
# EpisodeReturn: 185.64
# AverageReturn: 147.91
# EvalEpisodes: 10
# EvalEpisodeReturn: 140.06
# EvalAverageReturn: 161.2
# Time: 187
# ---------------------------------------
# ---------------------------------------
# Iterations: 18
# Steps: 72314
# Episodes: 2484
# EpisodeReturn: 174.65
# AverageReturn: 148.76
# EvalEpisodes: 10
# EvalEpisodeReturn: 175.89
# EvalAverageReturn: 165.32
# Time: 199
# ---------------------------------------
# ---------------------------------------
# Iterations: 19
# Steps: 76348
# Episodes: 2615
# EpisodeReturn: 179.23
# AverageReturn: 149.2
# EvalEpisodes: 10
# EvalEpisodeReturn: 156.51
# EvalAverageReturn: 166.23
# Time: 212
# ---------------------------------------
# ---------------------------------------
# Iterations: 20
# Steps: 80354
# Episodes: 2750
# EpisodeReturn: 168.06
# AverageReturn: 149.33
# EvalEpisodes: 10
# EvalEpisodeReturn: 188.63
# EvalAverageReturn: 169.31
# Time: 223
# ---------------------------------------
# ---------------------------------------
# Iterations: 21
# Steps: 84361
# Episodes: 2886
# EpisodeReturn: 179.46
# AverageReturn: 149.43
# EvalEpisodes: 10
# EvalEpisodeReturn: 146.23
# EvalAverageReturn: 165.6
# Time: 234
# ---------------------------------------
# ---------------------------------------
# Iterations: 22
# Steps: 88377
# Episodes: 3017
# EpisodeReturn: 157.12
# AverageReturn: 149.77
# EvalEpisodes: 10
# EvalEpisodeReturn: 145.39
# EvalAverageReturn: 169.52
# Time: 246
# ---------------------------------------
# ---------------------------------------
# Iterations: 23
# Steps: 92400
# Episodes: 3153
# EpisodeReturn: 151.26
# AverageReturn: 149.84
# EvalEpisodes: 10
# EvalEpisodeReturn: 161.33
# EvalAverageReturn: 165.43
# Time: 257
# ---------------------------------------
# ---------------------------------------
# Iterations: 24
# Steps: 96414
# Episodes: 3284
# EpisodeReturn: 196.15
# AverageReturn: 150.13
# EvalEpisodes: 10
# EvalEpisodeReturn: 178.1
# EvalAverageReturn: 175.21
# Time: 268
# ---------------------------------------
# ---------------------------------------
# Iterations: 25
# Steps: 100438
# Episodes: 3416
# EpisodeReturn: 217.13
# AverageReturn: 150.36
# EvalEpisodes: 10
# EvalEpisodeReturn: 226.36
# EvalAverageReturn: 175.09
# Time: 280
# ---------------------------------------
# ---------------------------------------
# Iterations: 26
# Steps: 104459
# Episodes: 3547
# EpisodeReturn: 145.45
# AverageReturn: 150.62
# EvalEpisodes: 10
# EvalEpisodeReturn: 178.89
# EvalAverageReturn: 168.02
# Time: 291
# ---------------------------------------
# ---------------------------------------
# Iterations: 27
# Steps: 108473
# Episodes: 3675
# EpisodeReturn: 218.11
# AverageReturn: 150.99
# EvalEpisodes: 10
# EvalEpisodeReturn: 156.47
# EvalAverageReturn: 163.14
# Time: 303
# ---------------------------------------
# ---------------------------------------
# Iterations: 28
# Steps: 112496
# Episodes: 3807
# EpisodeReturn: 158.87
# AverageReturn: 151.16
# EvalEpisodes: 10
# EvalEpisodeReturn: 145.3
# EvalAverageReturn: 161.45
# Time: 316
# ---------------------------------------
# ---------------------------------------
# Iterations: 29
# Steps: 116500
# Episodes: 3939
# EpisodeReturn: 83.23
# AverageReturn: 151.3
# EvalEpisodes: 10
# EvalEpisodeReturn: 140.24
# EvalAverageReturn: 183.29
# Time: 328
# ---------------------------------------
# ---------------------------------------
# Iterations: 30
# Steps: 120508
# Episodes: 4072
# EpisodeReturn: 120.42
# AverageReturn: 151.38
# EvalEpisodes: 10
# EvalEpisodeReturn: 169.56
# EvalAverageReturn: 160.67
# Time: 339
# ---------------------------------------

# %%
plt.show()
plt.plot(train_avg_ret)
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.title("train average rewards")

plt.show()
plt.plot(train_ep_ret)
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.title("train episode rewards")
# Out:
# Text(0.5, 1.0, 'train episode rewards')

# %%
plt.show()
plt.plot(eval_avg_ret)
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.title("test average rewards")

plt.show()
plt.plot(eval_ep_ret)
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.title("test episode rewards")
# Out:
# Text(0.5, 1.0, 'test episode rewards')
