# %% [markdown]
# # Proximal Policy Optimisation

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

from torch.utils.tensorboard import SummaryWriter

import argparse
from distutils.util import strtobool
import collections
import numpy as np
import gym
from gym.wrappers import TimeLimit, Monitor
from gym.spaces import Discrete, Box, MultiBinary, MultiDiscrete, Space
import time
import random
import os
import matplotlib.pyplot as plt
import time
import argparse
import datetime
from torch.distributions import Categorical, Normal

# %%
class ReplayBuffer(object):
    """
    A simple FIFO experience replay buffer for agents.
    """

    def __init__(self, obs_dim, act_dim, size, device):
        self.obs1_buf = np.zeros([size, obs_dim], dtype=np.float32)
        self.obs2_buf = np.zeros([size, obs_dim], dtype=np.float32)
        self.acts_buf = np.zeros([size, act_dim], dtype=np.float32)
        self.rews_buf = np.zeros(size, dtype=np.float32)
        self.done_buf = np.zeros(size, dtype=np.float32)
        self.ptr, self.size, self.max_size = 0, 0, size
        self.device = device

    def add(self, obs, act, rew, next_obs, done):
        self.obs1_buf[self.ptr] = obs
        self.obs2_buf[self.ptr] = next_obs
        self.acts_buf[self.ptr] = act
        self.rews_buf[self.ptr] = rew
        self.done_buf[self.ptr] = done
        self.ptr = (self.ptr+1) % self.max_size
        self.size = min(self.size+1, self.max_size)

    def sample(self, batch_size=64):
        idxs = np.random.randint(0, self.size, size=batch_size)
        return dict(obs1=torch.Tensor(self.obs1_buf[idxs]).to(self.device),
                    obs2=torch.Tensor(self.obs2_buf[idxs]).to(self.device),
                    acts=torch.Tensor(self.acts_buf[idxs]).to(self.device),
                    rews=torch.Tensor(self.rews_buf[idxs]).to(self.device),
                    done=torch.Tensor(self.done_buf[idxs]).to(self.device))


class Buffer(object):
    """
    A buffer for storing trajectories experienced by a agent interacting
    with the environment.
    """

    def __init__(self, obs_dim, act_dim, size, device, gamma=0.99, lam=0.97):
        self.obs_buf = np.zeros([size, obs_dim], dtype=np.float32)
        self.act_buf = np.zeros([size, act_dim], dtype=np.float32)
        self.rew_buf = np.zeros(size, dtype=np.float32)
        self.don_buf = np.zeros(size, dtype=np.float32)
        self.ret_buf = np.zeros(size, dtype=np.float32)
        self.adv_buf = np.zeros(size, dtype=np.float32)
        self.v_buf = np.zeros(size, dtype=np.float32)
        self.gamma, self.lam = gamma, lam
        self.ptr, self.max_size = 0, size
        self.device = device

    def add(self, obs, act, rew, don, v):
        assert self.ptr < self.max_size      # Buffer has to have room so you can store
        self.obs_buf[self.ptr] = obs
        self.act_buf[self.ptr] = act
        self.rew_buf[self.ptr] = rew
        self.don_buf[self.ptr] = don
        self.v_buf[self.ptr] = v
        self.ptr += 1

    def finish_path(self):
        previous_v = 0
        running_ret = 0
        running_adv = 0
        for t in reversed(range(len(self.rew_buf))):
            # The next two line computes rewards-to-go, to be targets for the value function
            running_ret = self.rew_buf[t] + self.gamma*(1-self.don_buf[t])*running_ret
            self.ret_buf[t] = running_ret

            # The next four lines implement GAE-Lambda advantage calculation
            running_del = self.rew_buf[t] + self.gamma*(1-self.don_buf[t])*previous_v - self.v_buf[t]
            running_adv = running_del + self.gamma*self.lam*(1-self.don_buf[t])*running_adv
            previous_v = self.v_buf[t]
            self.adv_buf[t] = running_adv
        # The next line implement the advantage normalization trick
        self.adv_buf = (self.adv_buf - self.adv_buf.mean()) / self.adv_buf.std()
        
    def get(self):
        assert self.ptr == self.max_size     # Buffer has to be full before you can get
        self.ptr = 0
        return dict(obs=torch.Tensor(self.obs_buf).to(self.device),
                    act=torch.Tensor(self.act_buf).to(self.device),
                    ret=torch.Tensor(self.ret_buf).to(self.device),
                    adv=torch.Tensor(self.adv_buf).to(self.device),
                    v=torch.Tensor(self.v_buf).to(self.device))

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

env = gym.make('Humanoid-v2')
seed = 1234
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
env.seed(seed)

obs_dim = env.observation_space.shape[0]
act_dim = env.action_space.shape[0]
act_limit = env.action_space.high[0]

print (obs_dim, act_dim, act_limit)
# Out:
# 376 17 0.4

# %%
# Hyper params
n_iters = 30
steps_per_iter = 4000
phase = 'train'
max_step = 1000

# %%
def identity(x):
    """Return input without any change."""
    return x

class MLP(nn.Module):
    def __init__(self, 
                 input_size, 
                 output_size, 
                 output_limit=1.0,
                 hidden_sizes=(64,64), 
                 activation=F.relu, 
                 output_activation=identity,
                 use_output_layer=True,
                 use_actor=False,
    ):
        super(MLP, self).__init__()

        self.input_size = input_size
        self.output_size = output_size
        self.output_limit = output_limit
        self.hidden_sizes = hidden_sizes
        self.activation = activation
        self.output_activation = output_activation
        self.use_output_layer = use_output_layer
        self.use_actor = use_actor

        # Set hidden layers
        self.hidden_layers = nn.ModuleList()
        in_size = self.input_size
        for next_size in self.hidden_sizes:
            fc = nn.Linear(in_size, next_size)
            in_size = next_size
            self.hidden_layers.append(fc)

        # Set output layers
        if self.use_output_layer:
            self.output_layer = nn.Linear(in_size, self.output_size)
        else:
            self.output_layer = identity

    def forward(self, x):
        for hidden_layer in self.hidden_layers:
            x = self.activation(hidden_layer(x))
        x = self.output_activation(self.output_layer(x))
        # If the network is used as actor network, make sure output is in correct range
        x = x * self.output_limit if self.use_actor else x   
        return x
    
class GaussianPolicy(MLP):
    def __init__(self, 
                 input_size, 
                 output_size, 
                 output_limit=1.0,
                 hidden_sizes=(64,64),
                 activation=torch.tanh,
    ):
        super(GaussianPolicy, self).__init__(
            input_size=input_size,
            output_size=output_size,
            hidden_sizes=hidden_sizes,
            activation=activation,
        )

        self.output_limit = output_limit
        self.log_std = np.ones(output_size, dtype=np.float32)
        self.log_std = torch.nn.Parameter(torch.Tensor(self.log_std))

    def forward(self, x, pi=None, use_pi=True):
        mu = super(GaussianPolicy, self).forward(x)
        std = torch.exp(self.log_std)

        dist = Normal(mu, std)
        if use_pi:
            pi = dist.sample()
        log_pi = dist.log_prob(pi).sum(dim=-1)

        # Make sure outputs are in correct range
        mu = mu * self.output_limit
        pi = pi * self.output_limit
        return mu, std, pi, log_pi
    
def hard_target_update(main, target):
    target.load_state_dict(main.state_dict())

def soft_target_update(main, target, tau=0.005):
    for main_param, target_param in zip(main.parameters(), target.parameters()):
        target_param.data.copy_(tau*main_param.data + (1.0-tau)*target_param.data)

# %%
class Agent(object):
   """
   An implementation of the Proximal Policy Optimization (PPO) (by clipping) agent, 
   with early stopping based on approximate KL.
   """

   def __init__(self,
                env,
                device,
                obs_dim,
                act_dim,
                act_limit,
                steps=0,
                gamma=0.99,
                lam=0.97,
                hidden_sizes=(64,64),
                sample_size=2048,
                train_policy_iters=80,
                train_vf_iters=80,
                clip_param=0.2,
                target_kl=0.01,
                policy_lr=3e-4,
                vf_lr=1e-3,
                eval_mode=False,
                policy_losses=list(),
                vf_losses=list(),
                kls=list(),
                logger=dict(),
   ):

      self.env = env
      self.device = device
      self.obs_dim = obs_dim
      self.act_dim = act_dim
      self.act_limit = act_limit
      self.steps = steps 
      self.gamma = gamma
      self.lam = lam
      self.hidden_sizes = hidden_sizes
      self.sample_size = sample_size
      self.train_policy_iters = train_policy_iters
      self.train_vf_iters = train_vf_iters
      self.clip_param = clip_param
      self.target_kl = target_kl
      self.policy_lr = policy_lr
      self.vf_lr = vf_lr
      self.eval_mode = eval_mode
      self.policy_losses = policy_losses
      self.vf_losses = vf_losses
      self.kls = kls
      self.logger = logger

      # Main network
      self.policy = GaussianPolicy(self.obs_dim, self.act_dim, self.act_limit).to(self.device)
      self.vf = MLP(self.obs_dim, 1, activation=torch.tanh).to(self.device)
      
      # Create optimizers
      self.policy_optimizer = optim.Adam(self.policy.parameters(), lr=self.policy_lr)
      self.vf_optimizer = optim.Adam(self.vf.parameters(), lr=self.vf_lr)
      
      # Experience buffer
      self.buffer = Buffer(self.obs_dim, self.act_dim, self.sample_size, self.device, self.gamma, self.lam)

   def compute_vf_loss(self, obs, ret, v_old):
      # Prediction V(s)
      v = self.vf(obs).squeeze(1)

      # Value loss
      clip_v = v_old + torch.clamp(v-v_old, -self.clip_param, self.clip_param)
      vf_loss = torch.max(F.mse_loss(v, ret), F.mse_loss(clip_v, ret)).mean()
      return vf_loss

   def compute_policy_loss(self, obs, act, adv, log_pi_old):
      # Prediction logπ(s)
      _, _, _, log_pi = self.policy(obs, act, use_pi=False)
      
      # Policy loss
      ratio = torch.exp(log_pi - log_pi_old)
      clip_adv = torch.clamp(ratio, 1.-self.clip_param, 1.+self.clip_param)*adv
      policy_loss = -torch.min(ratio*adv, clip_adv).mean()

      # A sample estimate for KL-divergence, easy to compute
      approx_kl = (log_pi_old - log_pi).mean()
      return policy_loss, approx_kl

   def train_model(self):
      batch = self.buffer.get()
      obs = batch['obs']
      act = batch['act']
      ret = batch['ret']
      adv = batch['adv']
      
      # Prediction logπ_old(s), V_old(s)
      _, _, _, log_pi_old = self.policy(obs, act, use_pi=False)
      log_pi_old = log_pi_old.detach()
      v_old = self.vf(obs).squeeze(1)
      v_old = v_old.detach()

      # Train policy with multiple steps of gradient descent
      for i in range(self.train_policy_iters):
         policy_loss, kl = self.compute_policy_loss(obs, act, adv, log_pi_old)
         
         # Early stopping at step i due to reaching max kl
         if kl > 1.5 * self.target_kl:
            break
         
         # Update policy network parameter
         self.policy_optimizer.zero_grad()
         policy_loss.backward()
         self.policy_optimizer.step()
      
      # Train value with multiple steps of gradient descent
      for i in range(self.train_vf_iters):
         vf_loss = self.compute_vf_loss(obs, ret, v_old)

         # Update value network parameter
         self.vf_optimizer.zero_grad()
         vf_loss.backward()
         self.vf_optimizer.step()

      # Save losses
      self.policy_losses.append(policy_loss.item())
      self.vf_losses.append(vf_loss.item())
      self.kls.append(kl.item())

   def run(self, max_step):
      step_number = 0
      total_reward = 0.

      obs = self.env.reset()
      done = False

      # Keep interacting until agent reaches a terminal state.
      while not (done or step_number == max_step):
#             env.render()

         if self.eval_mode:
            action, _, _, _ = self.policy(torch.Tensor(obs).to(self.device))
            action = action.detach().cpu().numpy()
            next_obs, reward, done, _ = self.env.step(action)
         else:
            self.steps += 1
            
            # Collect experience (s, a, r, s') using some policy
            _, _, action, _ = self.policy(torch.Tensor(obs).to(self.device))
            action = action.detach().cpu().numpy()
            next_obs, reward, done, _ = self.env.step(action)

            # Add experience to buffer
            v = self.vf(torch.Tensor(obs).to(self.device))
            self.buffer.add(obs, action, reward, done, v)
            
            # Start training when the number of experience is equal to sample size
            if self.steps == self.sample_size:
               self.buffer.finish_path()
               self.train_model()
               self.steps = 0

         total_reward += reward
         step_number += 1
         obs = next_obs
      
      # Save logs
      self.logger['LossPi'] = round(np.mean(self.policy_losses), 5)
      self.logger['LossV'] = round(np.mean(self.vf_losses), 5)
      self.logger['KL'] = round(np.mean(self.kls), 5)
      return step_number, total_reward

# %%
agent = Agent(env, device, obs_dim, act_dim, act_limit, sample_size=4096)

# %%
start_time = time.time()

total_num_steps = 0
train_sum_returns = 0.
train_num_episodes = 0
eval_mode = 0

train_avg_ret = []
train_ep_ret = []
eval_avg_ret = []
eval_ep_ret = []


for i in range(n_iters):
        # Perform the training phase, during which the agent learns
        if phase == 'train':
            train_step_count = 0

            while train_step_count <= steps_per_iter:
                eval_mode = False
                
                # Run one episode
                train_step_length, train_episode_return = agent.run(max_step)
                
                total_num_steps += train_step_length
                train_step_count += train_step_length
                train_sum_returns += train_episode_return
                train_num_episodes += 1

                train_average_return = train_sum_returns / train_num_episodes if train_num_episodes > 0 else 0.0
                
                train_avg_ret.append(train_average_return)
                train_ep_ret.append(train_episode_return)
                

        # Perform the evaluation phase -- no learning
        eval_sum_returns = 0.
        eval_num_episodes = 0
        eval_mode = True

        for _ in range(10):
            # Run one episode
            eval_step_length, eval_episode_return = agent.run(max_step)

            eval_sum_returns += eval_episode_return
            eval_num_episodes += 1

        eval_average_return = eval_sum_returns / eval_num_episodes if eval_num_episodes > 0 else 0.0
        eval_avg_ret.append(eval_average_return)
        eval_ep_ret.append(eval_episode_return)


        if phase == 'train':
            print('---------------------------------------')
            print('Iterations:', i + 1)
            print('Steps:', total_num_steps)
            print('Episodes:', train_num_episodes)
            print('EpisodeReturn:', round(train_episode_return, 2))
            print('AverageReturn:', round(train_average_return, 2))
            print('EvalEpisodes:', eval_num_episodes)
            print('EvalEpisodeReturn:', round(eval_episode_return, 2))
            print('EvalAverageReturn:', round(eval_average_return, 2))
            print('OtherLogs:', agent.logger)
            print('Time:', int(time.time() - start_time))
            print('---------------------------------------')

        
        print('---------------------------------------')
        print('EvalEpisodes:', eval_num_episodes)
        print('EvalEpisodeReturn:', round(eval_episode_return, 2))
        print('EvalAverageReturn:', round(eval_average_return, 2))
        print('Time:', int(time.time() - start_time))
        print('---------------------------------------')
# Out:
# /opt/conda/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /opt/conda/lib/python3.7/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# ---------------------------------------
# Iterations: 1
# Steps: 4031
# Episodes: 177
# EpisodeReturn: 164.14
# AverageReturn: 110.86
# EvalEpisodes: 10
# EvalEpisodeReturn: 191.79
# EvalAverageReturn: 124.51
# OtherLogs: {'LossPi': -0.09206, 'LossV': 4750.94141, 'KL': -0.00094}
# Time: 7
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 191.79
# EvalAverageReturn: 124.51
# Time: 7
# ---------------------------------------
# ---------------------------------------
# Iterations: 2
# Steps: 8039
# Episodes: 347
# EpisodeReturn: 261.71
# AverageReturn: 113.12
# EvalEpisodes: 10
# EvalEpisodeReturn: 193.94
# EvalAverageReturn: 125.56
# OtherLogs: {'LossPi': -0.09973, 'LossV': 4867.92114, 'KL': 0.00738}
# Time: 15
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 193.94
# EvalAverageReturn: 125.56
# Time: 15
# ---------------------------------------
# ---------------------------------------
# Iterations: 3
# Steps: 12050
# Episodes: 483
# EpisodeReturn: 164.04
# AverageReturn: 121.93
# EvalEpisodes: 10
# EvalEpisodeReturn: 76.21
# EvalAverageReturn: 103.6
# OtherLogs: {'LossPi': -0.07091, 'LossV': 5668.81396, 'KL': 0.01002}
# Time: 22
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 76.21
# EvalAverageReturn: 103.6
# Time: 22
# ---------------------------------------
# ---------------------------------------
# Iterations: 4
# Steps: 16064
# Episodes: 625
# EpisodeReturn: 136.59
# AverageReturn: 126.0
# EvalEpisodes: 10
# EvalEpisodeReturn: 128.93
# EvalAverageReturn: 134.58
# OtherLogs: {'LossPi': -0.05622, 'LossV': 5910.29944, 'KL': 0.01354}
# Time: 30
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 128.93
# EvalAverageReturn: 134.58
# Time: 30
# ---------------------------------------
# ---------------------------------------
# Iterations: 5
# Steps: 20081
# Episodes: 761
# EpisodeReturn: 106.78
# AverageReturn: 129.59
# EvalEpisodes: 10
# EvalEpisodeReturn: 161.97
# EvalAverageReturn: 118.74
# OtherLogs: {'LossPi': -0.0464, 'LossV': 6095.72764, 'KL': 0.01397}
# Time: 38
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 161.97
# EvalAverageReturn: 118.74
# Time: 38
# ---------------------------------------
# ---------------------------------------
# Iterations: 6
# Steps: 24109
# Episodes: 900
# EpisodeReturn: 181.26
# AverageReturn: 131.72
# EvalEpisodes: 10
# EvalEpisodeReturn: 181.59
# EvalAverageReturn: 190.83
# OtherLogs: {'LossPi': -0.03982, 'LossV': 6163.61694, 'KL': 0.01468}
# Time: 46
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 181.59
# EvalAverageReturn: 190.83
# Time: 46
# ---------------------------------------
# ---------------------------------------
# Iterations: 7
# Steps: 28121
# Episodes: 1033
# EpisodeReturn: 149.33
# AverageReturn: 133.85
# EvalEpisodes: 10
# EvalEpisodeReturn: 175.23
# EvalAverageReturn: 146.72
# OtherLogs: {'LossPi': -0.03522, 'LossV': 6426.65346, 'KL': 0.01531}
# Time: 53
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 175.23
# EvalAverageReturn: 146.72
# Time: 53
# ---------------------------------------
# ---------------------------------------
# Iterations: 8
# Steps: 32140
# Episodes: 1165
# EpisodeReturn: 116.04
# AverageReturn: 135.73
# EvalEpisodes: 10
# EvalEpisodeReturn: 92.53
# EvalAverageReturn: 150.75
# OtherLogs: {'LossPi': -0.032, 'LossV': 6407.21155, 'KL': 0.01647}
# Time: 61
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 92.53
# EvalAverageReturn: 150.75
# Time: 61
# ---------------------------------------
# ---------------------------------------
# Iterations: 9
# Steps: 36177
# Episodes: 1285
# EpisodeReturn: 202.19
# AverageReturn: 138.58
# EvalEpisodes: 10
# EvalEpisodeReturn: 146.67
# EvalAverageReturn: 129.79
# OtherLogs: {'LossPi': -0.02925, 'LossV': 6564.74642, 'KL': 0.0174}
# Time: 69
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 146.67
# EvalAverageReturn: 129.79
# Time: 69
# ---------------------------------------
# ---------------------------------------
# Iterations: 10
# Steps: 40179
# Episodes: 1407
# EpisodeReturn: 137.15
# AverageReturn: 140.74
# EvalEpisodes: 10
# EvalEpisodeReturn: 103.13
# EvalAverageReturn: 135.64
# OtherLogs: {'LossPi': -0.02714, 'LossV': 6628.0917, 'KL': 0.0184}
# Time: 77
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 103.13
# EvalAverageReturn: 135.64
# Time: 77
# ---------------------------------------
# ---------------------------------------
# Iterations: 11
# Steps: 44183
# Episodes: 1525
# EpisodeReturn: 160.25
# AverageReturn: 142.9
# EvalEpisodes: 10
# EvalEpisodeReturn: 305.76
# EvalAverageReturn: 178.74
# OtherLogs: {'LossPi': -0.02556, 'LossV': 6700.95885, 'KL': 0.01957}
# Time: 85
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 305.76
# EvalAverageReturn: 178.74
# Time: 85
# ---------------------------------------
# ---------------------------------------
# Iterations: 12
# Steps: 48225
# Episodes: 1636
# EpisodeReturn: 330.17
# AverageReturn: 145.5
# EvalEpisodes: 10
# EvalEpisodeReturn: 186.97
# EvalAverageReturn: 181.77
# OtherLogs: {'LossPi': -0.02425, 'LossV': 6807.56148, 'KL': 0.02071}
# Time: 93
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 186.97
# EvalAverageReturn: 181.77
# Time: 93
# ---------------------------------------
# ---------------------------------------
# Iterations: 13
# Steps: 52270
# Episodes: 1748
# EpisodeReturn: 237.15
# AverageReturn: 147.63
# EvalEpisodes: 10
# EvalEpisodeReturn: 218.22
# EvalAverageReturn: 191.46
# OtherLogs: {'LossPi': -0.02327, 'LossV': 7063.1466, 'KL': 0.022}
# Time: 101
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 218.22
# EvalAverageReturn: 191.46
# Time: 101
# ---------------------------------------
# ---------------------------------------
# Iterations: 14
# Steps: 56329
# Episodes: 1860
# EpisodeReturn: 294.81
# AverageReturn: 149.69
# EvalEpisodes: 10
# EvalEpisodeReturn: 136.8
# EvalAverageReturn: 208.25
# OtherLogs: {'LossPi': -0.02231, 'LossV': 7187.02954, 'KL': 0.02324}
# Time: 109
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 136.8
# EvalAverageReturn: 208.25
# Time: 109
# ---------------------------------------
# ---------------------------------------
# Iterations: 15
# Steps: 60330
# Episodes: 1958
# EpisodeReturn: 188.61
# AverageReturn: 152.37
# EvalEpisodes: 10
# EvalEpisodeReturn: 188.39
# EvalAverageReturn: 192.27
# OtherLogs: {'LossPi': -0.02158, 'LossV': 7320.10811, 'KL': 0.02462}
# Time: 117
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 188.39
# EvalAverageReturn: 192.27
# Time: 117
# ---------------------------------------
# ---------------------------------------
# Iterations: 16
# Steps: 64332
# Episodes: 2055
# EpisodeReturn: 245.58
# AverageReturn: 154.89
# EvalEpisodes: 10
# EvalEpisodeReturn: 157.61
# EvalAverageReturn: 165.88
# OtherLogs: {'LossPi': -0.02093, 'LossV': 7608.69803, 'KL': 0.0258}
# Time: 125
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 157.61
# EvalAverageReturn: 165.88
# Time: 125
# ---------------------------------------
# ---------------------------------------
# Iterations: 17
# Steps: 68381
# Episodes: 2152
# EpisodeReturn: 274.61
# AverageReturn: 157.34
# EvalEpisodes: 10
# EvalEpisodeReturn: 88.03
# EvalAverageReturn: 177.59
# OtherLogs: {'LossPi': -0.01985, 'LossV': 7874.53497, 'KL': 0.02788}
# Time: 134
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 88.03
# EvalAverageReturn: 177.59
# Time: 134
# ---------------------------------------
# ---------------------------------------
# Iterations: 18
# Steps: 72405
# Episodes: 2240
# EpisodeReturn: 194.41
# AverageReturn: 160.22
# EvalEpisodes: 10
# EvalEpisodeReturn: 194.91
# EvalAverageReturn: 229.26
# OtherLogs: {'LossPi': -0.01935, 'LossV': 8073.83879, 'KL': 0.02882}
# Time: 142
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 194.91
# EvalAverageReturn: 229.26
# Time: 142
# ---------------------------------------
# ---------------------------------------
# Iterations: 19
# Steps: 76474
# Episodes: 2329
# EpisodeReturn: 355.51
# AverageReturn: 162.93
# EvalEpisodes: 10
# EvalEpisodeReturn: 193.6
# EvalAverageReturn: 215.96
# OtherLogs: {'LossPi': -0.01901, 'LossV': 8245.91355, 'KL': 0.02986}
# Time: 151
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 193.6
# EvalAverageReturn: 215.96
# Time: 151
# ---------------------------------------
# ---------------------------------------
# Iterations: 20
# Steps: 80551
# Episodes: 2416
# EpisodeReturn: 398.01
# AverageReturn: 165.56
# EvalEpisodes: 10
# EvalEpisodeReturn: 214.13
# EvalAverageReturn: 262.16
# OtherLogs: {'LossPi': -0.01872, 'LossV': 8376.85238, 'KL': 0.03089}
# Time: 159
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 214.13
# EvalAverageReturn: 262.16
# Time: 159
# ---------------------------------------
# ---------------------------------------
# Iterations: 21
# Steps: 84552
# Episodes: 2498
# EpisodeReturn: 223.56
# AverageReturn: 168.15
# EvalEpisodes: 10
# EvalEpisodeReturn: 274.84
# EvalAverageReturn: 272.79
# OtherLogs: {'LossPi': -0.01844, 'LossV': 8649.13119, 'KL': 0.03195}
# Time: 167
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 274.84
# EvalAverageReturn: 272.79
# Time: 167
# ---------------------------------------
# ---------------------------------------
# Iterations: 22
# Steps: 88556
# Episodes: 2576
# EpisodeReturn: 163.32
# AverageReturn: 170.81
# EvalEpisodes: 10
# EvalEpisodeReturn: 459.34
# EvalAverageReturn: 250.31
# OtherLogs: {'LossPi': -0.01824, 'LossV': 8790.80535, 'KL': 0.03318}
# Time: 176
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 459.34
# EvalAverageReturn: 250.31
# Time: 176
# ---------------------------------------
# ---------------------------------------
# Iterations: 23
# Steps: 92584
# Episodes: 2650
# EpisodeReturn: 266.58
# AverageReturn: 173.67
# EvalEpisodes: 10
# EvalEpisodeReturn: 204.84
# EvalAverageReturn: 246.2
# OtherLogs: {'LossPi': -0.01796, 'LossV': 9087.68406, 'KL': 0.0343}
# Time: 184
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 204.84
# EvalAverageReturn: 246.2
# Time: 184
# ---------------------------------------
# ---------------------------------------
# Iterations: 24
# Steps: 96592
# Episodes: 2728
# EpisodeReturn: 110.11
# AverageReturn: 176.06
# EvalEpisodes: 10
# EvalEpisodeReturn: 386.15
# EvalAverageReturn: 233.95
# OtherLogs: {'LossPi': -0.01771, 'LossV': 9264.66139, 'KL': 0.03519}
# Time: 193
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 386.15
# EvalAverageReturn: 233.95
# Time: 193
# ---------------------------------------
# ---------------------------------------
# Iterations: 25
# Steps: 100612
# Episodes: 2803
# EpisodeReturn: 426.38
# AverageReturn: 178.56
# EvalEpisodes: 10
# EvalEpisodeReturn: 188.98
# EvalAverageReturn: 294.77
# OtherLogs: {'LossPi': -0.01764, 'LossV': 9361.39091, 'KL': 0.03641}
# Time: 201
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 188.98
# EvalAverageReturn: 294.77
# Time: 201
# ---------------------------------------
# ---------------------------------------
# Iterations: 26
# Steps: 104643
# Episodes: 2878
# EpisodeReturn: 175.76
# AverageReturn: 180.88
# EvalEpisodes: 10
# EvalEpisodeReturn: 345.47
# EvalAverageReturn: 287.41
# OtherLogs: {'LossPi': -0.01753, 'LossV': 9529.47691, 'KL': 0.03744}
# Time: 210
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 345.47
# EvalAverageReturn: 287.41
# Time: 210
# ---------------------------------------
# ---------------------------------------
# Iterations: 27
# Steps: 108682
# Episodes: 2952
# EpisodeReturn: 283.08
# AverageReturn: 183.23
# EvalEpisodes: 10
# EvalEpisodeReturn: 462.04
# EvalAverageReturn: 291.91
# OtherLogs: {'LossPi': -0.01756, 'LossV': 9788.8997, 'KL': 0.04025}
# Time: 219
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 462.04
# EvalAverageReturn: 291.91
# Time: 219
# ---------------------------------------
# ---------------------------------------
# Iterations: 28
# Steps: 112743
# Episodes: 3017
# EpisodeReturn: 357.8
# AverageReturn: 186.04
# EvalEpisodes: 10
# EvalEpisodeReturn: 601.67
# EvalAverageReturn: 302.08
# OtherLogs: {'LossPi': -0.01748, 'LossV': 10014.01567, 'KL': 0.04209}
# Time: 228
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 601.67
# EvalAverageReturn: 302.08
# Time: 228
# ---------------------------------------
# ---------------------------------------
# Iterations: 29
# Steps: 116786
# Episodes: 3087
# EpisodeReturn: 300.6
# AverageReturn: 188.38
# EvalEpisodes: 10
# EvalEpisodeReturn: 283.98
# EvalAverageReturn: 273.58
# OtherLogs: {'LossPi': -0.01757, 'LossV': 10161.34726, 'KL': 0.04416}
# Time: 237
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 283.98
# EvalAverageReturn: 273.58
# Time: 237
# ---------------------------------------
# ---------------------------------------
# Iterations: 30
# Steps: 120792
# Episodes: 3156
# EpisodeReturn: 278.19
# AverageReturn: 190.61
# EvalEpisodes: 10
# EvalEpisodeReturn: 365.23
# EvalAverageReturn: 358.2
# OtherLogs: {'LossPi': -0.01763, 'LossV': 10223.25731, 'KL': 0.04592}
# Time: 246
# ---------------------------------------
# ---------------------------------------
# EvalEpisodes: 10
# EvalEpisodeReturn: 365.23
# EvalAverageReturn: 358.2
# Time: 246
# ---------------------------------------

# %%
plt.show()
plt.plot(train_avg_ret)

plt.show()
plt.plot(train_ep_ret)

# %%
plt.show()
plt.plot(eval_avg_ret)

plt.show()
plt.plot(eval_ep_ret)
