# %%
import gym
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.distributions as distributions

import matplotlib.pyplot as plt
import numpy as np
import gym
from tqdm import tqdm
import random
import warnings
warnings.filterwarnings('ignore')
import time
# Out:
# /opt/conda/lib/python3.7/site-packages/ale_py/roms/utils.py:90: DeprecationWarning: SelectableGroups dict interface is deprecated. Use select.
#   for external in metadata.entry_points().get(self.group, []):

# %%
env = gym.make('Humanoid-v2')
env = gym.make('Humanoid-v2')

SEED = 333

env.seed(SEED);
np.random.seed(SEED);
random.seed(SEED)
torch.manual_seed(SEED);

# %%
discrete_action_space_dim = 9
input_dim = env.observation_space.shape[0]
hidden_dim = 765
output_dim = env.action_space.shape[0] * discrete_action_space_dim
device = torch.device('cuda')
print (input_dim, output_dim)
# Out:
# 376 153

# %%
# Multi Layer Percpetron architecture, to be used as a non-linear Q value function approximator
class MLP(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, dropout = 0.5):
        super().__init__()

        self.fc_1 = nn.Linear(input_dim, hidden_dim)
        self.fc_2 = nn.Linear(hidden_dim, output_dim)
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(dropout)
        self.maxpool = nn.MaxPool1d(discrete_action_space_dim, stride=discrete_action_space_dim, return_indices=True)

    def forward(self, x):
        x = self.fc_1(x)
        x = self.dropout(x)
        x = self.relu(x)
        x = self.fc_2(x)
        x1, indices = self.maxpool(x)
        return x1, indices

# %%
def init_weights(m):
    if type(m) == nn.Linear:
        torch.nn.init.kaiming_normal_(m.weight)
        m.bias.data.fill_(0)
 
# Helper function to get action from action index output of the Neural Net
def get_actions(action_indices):
    actions = [-0.4, -0.3, -0.2, -0.1, 0.0, 0.1, 0.2, 0.3, 0.4]
    ret_actions = np.zeros(env.action_space.shape[0])
    for i in range(0, len(action_indices)):
        index = action_indices[i] - i*discrete_action_space_dim
        ret_actions[i] = actions[index]
    return ret_actions

# %%
# Define the Neural Net
q_network = MLP(input_dim, hidden_dim, output_dim).to(device)
q_network.apply(init_weights)
# Out:
# MLP(
#   (fc_1): Linear(in_features=376, out_features=765, bias=True)
#   (fc_2): Linear(in_features=765, out_features=153, bias=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0.5, inplace=False)
#   (maxpool): MaxPool1d(kernel_size=9, stride=9, padding=0, dilation=1, ceil_mode=False)
# )

# %%
LEARNING_RATE = 7.5e-4 

optimizer = optim.Adam(q_network.parameters(), lr = LEARNING_RATE)

# Hyper params
discount_factor = 0.8
epsilon = 0.9
decay_rate = 0.9965
n_iters = 30
steps_per_iter = 4000
phase = 'train'
max_step = 1000

# %%
def update_network(q_network, state, action, reward, next_state, discount_factor, optimizer):
    q_vals, action_indices = q_network(state)
    action_preds = get_actions(action_indices.view((-1)))

    with torch.no_grad():
        q_next_vals, action_next_indices = q_network(next_state)
        targets = reward + q_next_vals.sum() * discount_factor

    # Compute loss
    loss = F.smooth_l1_loss(targets.detach(), q_vals)
    
    optimizer.zero_grad()
    
    loss.backward()

    nn.utils.clip_grad_norm_(q_network.parameters(), 0.5)

    optimizer.step()
    
    return loss.item()

# %%
# Run for each episode
def agent_run(max_steps, global_steps, epsilon, eval_mode):
    
    done = False
    episode_reward = 0
    step_count = 0

    state = env.reset()
    state = torch.FloatTensor(state).unsqueeze(0).to(device)

    for steps in range(max_steps):
        
        # Pick an action using epsilon-greedy policy
        if np.random.random() < epsilon:
            action = env.action_space.sample()
        else:
            q_pred, action_indices = q_network(state)
            action = get_actions(action_indices.view((-1)))

        # Take the chosen action in the env and collect reward
        next_state, reward, done, _ = env.step(action)
        next_state = torch.FloatTensor(next_state).unsqueeze(0).to(device)
        episode_reward += reward

        # Compute Loss on the batch and optimise the model using back prop
        loss = update_network(q_network, state, action, reward, next_state, discount_factor, optimizer)
        state = next_state
        step_count+=1
        
        # Keep interacting until agent reaches a terminal state.
        if done:
            break

    return step_count, episode_reward

# %%
### This is the actual train/eval loop.
# We run 10 episodes of evaluation for every 4000 steps (steps_per_iter) taken by the agent in the environment during training

start_time = time.time()

total_num_steps = 0
train_sum_returns = 0.
train_num_episodes = 0
eval_mode = False

train_avg_ret = []
train_ep_ret = []
eval_avg_ret = []
eval_ep_ret = []
epsilon = 0.9
decay_rate = 0.995

for i in range(n_iters):
        # Perform the training phase, during which the agent learns
        if phase == 'train':
            train_step_count = 0
            while train_step_count <= steps_per_iter:
                eval_mode = False
                epsilon = max(epsilon*decay_rate, 0.1)
                
                # Run one episode
                train_step_length, train_episode_return = agent_run(max_step, i, epsilon, eval_mode)
                
                total_num_steps += train_step_length
                train_step_count += train_step_length
                train_sum_returns += train_episode_return
                train_num_episodes += 1

                train_average_return = train_sum_returns / train_num_episodes if train_num_episodes > 0 else 0.0
                
                train_avg_ret.append(train_average_return)
                train_ep_ret.append(train_episode_return)


        # Perform the evaluation phase -- no learning
        eval_sum_returns = 0.
        eval_num_episodes = 0
        eval_mode = True

        for _ in range(10):
            # Run one episode
            eval_step_length, eval_episode_return = agent_run(max_step, i, 0, eval_mode)

            eval_sum_returns += eval_episode_return
            eval_num_episodes += 1

        eval_average_return = eval_sum_returns / eval_num_episodes if eval_num_episodes > 0 else 0.0
        eval_avg_ret.append(eval_average_return)
        eval_ep_ret.append(eval_episode_return)


        if phase == 'train':
            print('---------------------------------------')
            print('Iterations:', i + 1)
            print('Steps:', total_num_steps)
            print('Episodes:', train_num_episodes)
            print('EpisodeReturn:', round(train_episode_return, 2))
            print('AverageReturn:', round(train_average_return, 2))
            print('EvalEpisodes:', eval_num_episodes)
            print('EvalEpisodeReturn:', round(eval_episode_return, 2))
            print('EvalAverageReturn:', round(eval_average_return, 2))
            print('Time:', int(time.time() - start_time))
            print('---------------------------------------')
        else:
            print('---------------------------------------')
            print('EvalEpisodes:', eval_num_episodes)
            print('EvalEpisodeReturn:', round(eval_episode_return, 2))
            print('EvalAverageReturn:', round(eval_average_return, 2))
            print('Time:', int(time.time() - start_time))
            print('---------------------------------------')
# Out:
# ---------------------------------------
# Iterations: 1
# Steps: 4022
# Episodes: 178
# EpisodeReturn: 133.43
# AverageReturn: 108.09
# EvalEpisodes: 10
# EvalEpisodeReturn: 73.12
# EvalAverageReturn: 78.86
# Time: 20
# ---------------------------------------
# ---------------------------------------
# Iterations: 2
# Steps: 8034
# Episodes: 387
# EpisodeReturn: 87.4
# AverageReturn: 98.03
# EvalEpisodes: 10
# EvalEpisodeReturn: 77.87
# EvalAverageReturn: 79.33
# Time: 42
# ---------------------------------------
# ---------------------------------------
# Iterations: 3
# Steps: 12042
# Episodes: 608
# EpisodeReturn: 86.25
# AverageReturn: 93.1
# EvalEpisodes: 10
# EvalEpisodeReturn: 78.97
# EvalAverageReturn: 78.48
# Time: 67
# ---------------------------------------
# ---------------------------------------
# Iterations: 4
# Steps: 16046
# Episodes: 836
# EpisodeReturn: 80.89
# AverageReturn: 90.13
# EvalEpisodes: 10
# EvalEpisodeReturn: 77.96
# EvalAverageReturn: 77.4
# Time: 102
# ---------------------------------------
# ---------------------------------------
# Iterations: 5
# Steps: 20050
# Episodes: 1061
# EpisodeReturn: 77.85
# AverageReturn: 88.6
# EvalEpisodes: 10
# EvalEpisodeReturn: 82.09
# EvalAverageReturn: 77.85
# Time: 136
# ---------------------------------------
# ---------------------------------------
# Iterations: 6
# Steps: 24061
# Episodes: 1287
# EpisodeReturn: 87.34
# AverageReturn: 87.6
# EvalEpisodes: 10
# EvalEpisodeReturn: 82.49
# EvalAverageReturn: 78.66
# Time: 170
# ---------------------------------------
# ---------------------------------------
# Iterations: 7
# Steps: 28073
# Episodes: 1511
# EpisodeReturn: 82.97
# AverageReturn: 86.97
# EvalEpisodes: 10
# EvalEpisodeReturn: 79.34
# EvalAverageReturn: 80.92
# Time: 204
# ---------------------------------------
# ---------------------------------------
# Iterations: 8
# Steps: 32084
# Episodes: 1736
# EpisodeReturn: 82.41
# AverageReturn: 86.47
# EvalEpisodes: 10
# EvalEpisodeReturn: 78.79
# EvalAverageReturn: 80.42
# Time: 238
# ---------------------------------------
# ---------------------------------------
# Iterations: 9
# Steps: 36093
# Episodes: 1958
# EpisodeReturn: 82.96
# AverageReturn: 86.19
# EvalEpisodes: 10
# EvalEpisodeReturn: 72.86
# EvalAverageReturn: 78.87
# Time: 272
# ---------------------------------------
# ---------------------------------------
# Iterations: 10
# Steps: 40095
# Episodes: 2182
# EpisodeReturn: 79.19
# AverageReturn: 85.88
# EvalEpisodes: 10
# EvalEpisodeReturn: 78.22
# EvalAverageReturn: 78.16
# Time: 306
# ---------------------------------------
# ---------------------------------------
# Iterations: 11
# Steps: 44113
# Episodes: 2408
# EpisodeReturn: 86.28
# AverageReturn: 85.6
# EvalEpisodes: 10
# EvalEpisodeReturn: 73.26
# EvalAverageReturn: 79.73
# Time: 341
# ---------------------------------------
# ---------------------------------------
# Iterations: 12
# Steps: 48125
# Episodes: 2632
# EpisodeReturn: 78.88
# AverageReturn: 85.41
# EvalEpisodes: 10
# EvalEpisodeReturn: 79.42
# EvalAverageReturn: 79.11
# Time: 375
# ---------------------------------------
# ---------------------------------------
# Iterations: 13
# Steps: 52129
# Episodes: 2858
# EpisodeReturn: 86.57
# AverageReturn: 85.2
# EvalEpisodes: 10
# EvalEpisodeReturn: 82.17
# EvalAverageReturn: 77.28
# Time: 402
# ---------------------------------------
# ---------------------------------------
# Iterations: 14
# Steps: 56146
# Episodes: 3085
# EpisodeReturn: 90.89
# AverageReturn: 85.01
# EvalEpisodes: 10
# EvalEpisodeReturn: 73.13
# EvalAverageReturn: 78.99
# Time: 427
# ---------------------------------------
# ---------------------------------------
# Iterations: 15
# Steps: 60152
# Episodes: 3309
# EpisodeReturn: 78.6
# AverageReturn: 84.9
# EvalEpisodes: 10
# EvalEpisodeReturn: 78.07
# EvalAverageReturn: 79.88
# Time: 452
# ---------------------------------------
# ---------------------------------------
# Iterations: 16
# Steps: 64160
# Episodes: 3531
# EpisodeReturn: 77.94
# AverageReturn: 84.84
# EvalEpisodes: 10
# EvalEpisodeReturn: 77.86
# EvalAverageReturn: 79.44
# Time: 477
# ---------------------------------------
# ---------------------------------------
# Iterations: 17
# Steps: 68164
# Episodes: 3752
# EpisodeReturn: 81.29
# AverageReturn: 84.81
# EvalEpisodes: 10
# EvalEpisodeReturn: 78.79
# EvalAverageReturn: 78.42
# Time: 502
# ---------------------------------------
# ---------------------------------------
# Iterations: 18
# Steps: 72166
# Episodes: 3974
# EpisodeReturn: 86.88
# AverageReturn: 84.76
# EvalEpisodes: 10
# EvalEpisodeReturn: 75.73
# EvalAverageReturn: 78.9
# Time: 527
# ---------------------------------------
# ---------------------------------------
# Iterations: 19
# Steps: 76176
# Episodes: 4201
# EpisodeReturn: 87.31
# AverageReturn: 84.64
# EvalEpisodes: 10
# EvalEpisodeReturn: 82.59
# EvalAverageReturn: 77.92
# Time: 553
# ---------------------------------------
# ---------------------------------------
# Iterations: 20
# Steps: 80189
# Episodes: 4424
# EpisodeReturn: 78.59
# AverageReturn: 84.59
# EvalEpisodes: 10
# EvalEpisodeReturn: 73.09
# EvalAverageReturn: 76.64
# Time: 578
# ---------------------------------------
# ---------------------------------------
# Iterations: 21
# Steps: 84202
# Episodes: 4650
# EpisodeReturn: 91.68
# AverageReturn: 84.51
# EvalEpisodes: 10
# EvalEpisodeReturn: 77.65
# EvalAverageReturn: 78.24
# Time: 603
# ---------------------------------------
# ---------------------------------------
# Iterations: 22
# Steps: 88216
# Episodes: 4872
# EpisodeReturn: 78.54
# AverageReturn: 84.48
# EvalEpisodes: 10
# EvalEpisodeReturn: 77.83
# EvalAverageReturn: 78.96
# Time: 623
# ---------------------------------------
# ---------------------------------------
# Iterations: 23
# Steps: 92224
# Episodes: 5095
# EpisodeReturn: 91.24
# AverageReturn: 84.44
# EvalEpisodes: 10
# EvalEpisodeReturn: 78.65
# EvalAverageReturn: 76.15
# Time: 636
# ---------------------------------------
# ---------------------------------------
# Iterations: 24
# Steps: 96226
# Episodes: 5320
# EpisodeReturn: 90.41
# AverageReturn: 84.38
# EvalEpisodes: 10
# EvalEpisodeReturn: 78.17
# EvalAverageReturn: 78.64
# Time: 650
# ---------------------------------------
# ---------------------------------------
# Iterations: 25
# Steps: 100238
# Episodes: 5544
# EpisodeReturn: 87.47
# AverageReturn: 84.34
# EvalEpisodes: 10
# EvalEpisodeReturn: 78.61
# EvalAverageReturn: 79.13
# Time: 664
# ---------------------------------------
# ---------------------------------------
# Iterations: 26
# Steps: 104245
# Episodes: 5768
# EpisodeReturn: 87.24
# AverageReturn: 84.3
# EvalEpisodes: 10
# EvalEpisodeReturn: 82.4
# EvalAverageReturn: 81.37
# Time: 678
# ---------------------------------------
# ---------------------------------------
# Iterations: 27
# Steps: 108250
# Episodes: 5991
# EpisodeReturn: 90.63
# AverageReturn: 84.27
# EvalEpisodes: 10
# EvalEpisodeReturn: 82.34
# EvalAverageReturn: 79.47
# Time: 692
# ---------------------------------------
# ---------------------------------------
# Iterations: 28
# Steps: 112265
# Episodes: 6216
# EpisodeReturn: 78.13
# AverageReturn: 84.23
# EvalEpisodes: 10
# EvalEpisodeReturn: 78.05
# EvalAverageReturn: 79.28
# Time: 713
# ---------------------------------------
# ---------------------------------------
# Iterations: 29
# Steps: 116272
# Episodes: 6437
# EpisodeReturn: 86.93
# AverageReturn: 84.23
# EvalEpisodes: 10
# EvalEpisodeReturn: 78.08
# EvalAverageReturn: 78.55
# Time: 738
# ---------------------------------------
# ---------------------------------------
# Iterations: 30
# Steps: 120282
# Episodes: 6661
# EpisodeReturn: 78.51
# AverageReturn: 84.2
# EvalEpisodes: 10
# EvalEpisodeReturn: 82.18
# EvalAverageReturn: 79.79
# Time: 763
# ---------------------------------------

# %%
plt.show()
plt.plot(train_avg_ret)
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.title("train average rewards")

plt.show()
plt.plot(train_ep_ret)
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.title("train episode rewards")
# Out:
# Text(0.5, 1.0, 'train episode rewards')

# %%
plt.show()
plt.plot(eval_avg_ret)
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.title("test average rewards")

plt.show()
plt.plot(eval_ep_ret)
plt.xlabel("Episodes")
plt.ylabel("Rewards")
plt.title("test episode rewards")
# Out:
# Text(0.5, 1.0, 'test episode rewards')

# %%
flag = ""

# %%
from datetime import datetime

now = datetime.now() # current date and time
date_time = str(now.strftime("%m:%d:%Y_%H:%M:%S"))
print (date_time)


algo = "QLearning_FuncApprox"
path = "Results/" + algo + date_time + flag
np.save(path +"_train_avg", train_avg_ret)
np.save(path + "_test_avg", eval_avg_ret)
np.save(path +"_train_ep", train_ep_ret)
np.save(path + "_test_ep", eval_ep_ret)
# Out:
# 12:10:2021_07:21:49

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# <AxesSubplot:>
